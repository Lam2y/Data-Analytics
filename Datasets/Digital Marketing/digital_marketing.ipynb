# %%
import numpy as np
import pandas as pd

df=pd.read_csv('digital_marketing_campaign_dataset.csv')

# %%
df.head()
# Out:
#    CustomerID  Age  Gender  Income CampaignChannel CampaignType      AdSpend  \
# 0        8000   56  Female  136912    Social Media    Awareness  6497.870068
# 1        8001   69    Male   41760           Email    Retention  3898.668606
# 2        8002   46  Female   88456             PPC    Awareness  1546.429596
# 3        8003   32  Female   44085             PPC   Conversion   539.525936
# 4        8004   60  Female   83964             PPC   Conversion  1678.043573
#
#    ClickThroughRate  ConversionRate  WebsiteVisits  PagesPerVisit  TimeOnSite  \
# 0          0.043919        0.088031              0       2.399017    7.396803
# 1          0.155725        0.182725             42       2.917138    5.352549
# 2          0.277490        0.076423              2       8.223619   13.794901
# 3          0.137611        0.088004             47       4.540939   14.688363
# 4          0.252851        0.109940              0       2.046847   13.993370
#
# ...

# %%
df.isna().sum()
# Out:
# CustomerID             0
# Age                    0
# Gender                 0
# Income                 0
# CampaignChannel        0
# CampaignType           0
# AdSpend                0
# ClickThroughRate       0
# ConversionRate         0
# WebsiteVisits          0
# PagesPerVisit          0
# TimeOnSite             0
# SocialShares           0
# EmailOpens             0
# EmailClicks            0
# PreviousPurchases      0
# LoyaltyPoints          0
# AdvertisingPlatform    0
# AdvertisingTool        0
# Conversion             0
# dtype: int64

# %%
df_array = np.array(df)
df_1D = np.array(df.iloc[0])
df_2D = np.array(df.iloc[0:3])
df_3D = np.array(df.iloc[0:3,4])

# %%
df.duplicated()==True
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7995    False
# 7996    False
# 7997    False
# 7998    False
# 7999    False
# Length: 8000, dtype: bool

# %%
df1 = pd.DataFrame( df.iloc[0:5], index = range(0,6), columns=df.columns)
df1
# Out:
#    CustomerID   Age  Gender    Income CampaignChannel CampaignType  \
# 0      8000.0  56.0  Female  136912.0    Social Media    Awareness
# 1      8001.0  69.0    Male   41760.0           Email    Retention
# 2      8002.0  46.0  Female   88456.0             PPC    Awareness
# 3      8003.0  32.0  Female   44085.0             PPC   Conversion
# 4      8004.0  60.0  Female   83964.0             PPC   Conversion
# 5         NaN   NaN     NaN       NaN             NaN          NaN
#
#        AdSpend  ClickThroughRate  ConversionRate  WebsiteVisits  \
# 0  6497.870068          0.043919        0.088031            0.0
# 1  3898.668606          0.155725        0.182725           42.0
# 2  1546.429596          0.277490        0.076423            2.0
# 3   539.525936          0.137611        0.088004           47.0
# 4  1678.043573          0.252851        0.109940            0.0
# 5          NaN               NaN             NaN            NaN
#
# ...

# %%
df.isna().sum()
# Out:
# CustomerID             0
# Age                    0
# Gender                 0
# Income                 0
# CampaignChannel        0
# CampaignType           0
# AdSpend                0
# ClickThroughRate       0
# ConversionRate         0
# WebsiteVisits          0
# PagesPerVisit          0
# TimeOnSite             0
# SocialShares           0
# EmailOpens             0
# EmailClicks            0
# PreviousPurchases      0
# LoyaltyPoints          0
# AdvertisingPlatform    0
# AdvertisingTool        0
# Conversion             0
# dtype: int64

# %%
df_agg = df.groupby('CampaignChannel')[['AdSpend']].sum()
df_agg
# Out:
#                       AdSpend
# CampaignChannel
# Email            7.871576e+06
# PPC              8.199237e+06
# Referral         8.653519e+06
# SEO              7.740904e+06
# Social Media     7.542323e+06

# %%
import matplotlib.pyplot as plt

plt.figure( figsize=(10,6) )
plt.stackplot( df_agg.index, df_agg['AdSpend'] )
plt.plot()
# Out:
# []

# %%
plt.figure(figsize=(10,6))
plt.errorbar( df_agg.index, df_agg['AdSpend'])
plt.show()
