# %%
import numpy as np
import pandas as pd
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_2524\3269992828.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df=pd.read_csv('Impact_of_Remote_Work_on_Mental_Health.csv')
df.head()
# Out:
#   Employee_ID  Age      Gender           Job_Role    Industry  \
# 0     EMP0001   32  Non-binary                 HR  Healthcare
# 1     EMP0002   40      Female     Data Scientist          IT
# 2     EMP0003   59  Non-binary  Software Engineer   Education
# 3     EMP0004   27        Male  Software Engineer     Finance
# 4     EMP0005   49        Male              Sales  Consulting
#
#    Years_of_Experience Work_Location  Hours_Worked_Per_Week  \
# 0                   13        Hybrid                     47
# 1                    3        Remote                     52
# 2                   22        Hybrid                     46
# 3                   20        Onsite                     32
# 4                   32        Onsite                     35
#
#    Number_of_Virtual_Meetings  Work_Life_Balance_Rating Stress_Level  \
# 0                           7                         2       Medium
# 1                           4                         1       Medium
# 2                          11                         5       Medium
# 3                           8                         4         High
# 4                          12                         2         High
#
#   Mental_Health_Condition Access_to_Mental_Health_Resources  \
# 0              Depression                                No
# 1                 Anxiety                                No
# 2                 Anxiety                                No
# 3              Depression                               Yes
# 4                     NaN                               Yes
#
#   Productivity_Change  Social_Isolation_Rating Satisfaction_with_Remote_Work  \
# 0            Decrease                        1                   Unsatisfied
# 1            Increase                        3                     Satisfied
# 2           No Change                        4                   Unsatisfied
# 3            Increase                        3                   Unsatisfied
# 4            Decrease                        3                   Unsatisfied
#
#    Company_Support_for_Remote_Work Physical_Activity Sleep_Quality  \
# 0                                1            Weekly          Good
# 1                                2            Weekly          Good
# 2                                5               NaN          Poor
# 3                                3               NaN          Poor
# 4                                3            Weekly       Average
#
#           Region
# 0         Europe
# 1           Asia
# 2  North America
# 3         Europe
# 4  North America

# %%
df1 = pd.DataFrame( df.iloc[0:3],range(1,3), columns=df.columns)
df1
# Out:
#   Employee_ID  Age      Gender           Job_Role   Industry  \
# 1     EMP0002   40      Female     Data Scientist         IT
# 2     EMP0003   59  Non-binary  Software Engineer  Education
#
#    Years_of_Experience Work_Location  Hours_Worked_Per_Week  \
# 1                    3        Remote                     52
# 2                   22        Hybrid                     46
#
#    Number_of_Virtual_Meetings  Work_Life_Balance_Rating Stress_Level  \
# 1                           4                         1       Medium
# 2                          11                         5       Medium
#
#   Mental_Health_Condition Access_to_Mental_Health_Resources  \
# 1                 Anxiety                                No
# 2                 Anxiety                                No
#
#   Productivity_Change  Social_Isolation_Rating Satisfaction_with_Remote_Work  \
# 1            Increase                        3                     Satisfied
# 2           No Change                        4                   Unsatisfied
#
#    Company_Support_for_Remote_Work Physical_Activity Sleep_Quality  \
# 1                                2            Weekly          Good
# 2                                5               NaN          Poor
#
#           Region
# 1           Asia
# 2  North America

# %%
df.isna().sum()
# Out:
# Employee_ID                             0
# Age                                     0
# Gender                                  0
# Job_Role                                0
# Industry                                0
# Years_of_Experience                     0
# Work_Location                           0
# Hours_Worked_Per_Week                   0
# Number_of_Virtual_Meetings              0
# Work_Life_Balance_Rating                0
# Stress_Level                            0
# Mental_Health_Condition              1196
# Access_to_Mental_Health_Resources       0
# Productivity_Change                     0
# Social_Isolation_Rating                 0
# Satisfaction_with_Remote_Work           0
# Company_Support_for_Remote_Work         0
# Physical_Activity                    1629
# Sleep_Quality                           0
# Region                                  0
# dtype: int64

# %%
df['Physical_Activity'].value_counts()
# Out:
# Physical_Activity
# Weekly    1755
# Daily     1616
# Name: count, dtype: int64

# %%
df['Mental_Health_Condition'].value_counts()
# Out:
# Mental_Health_Condition
# Burnout       1280
# Anxiety       1278
# Depression    1246
# Name: count, dtype: int64

# %%
df['Mental_Health_Condition']=df['Mental_Health_Condition'].fillna('Good')

# %%
df['Physical_Activity'].fillna('Never',inplace=True)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_2524\3914380561.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Physical_Activity'].fillna('Never',inplace=True)

# %%
df.to_excel('Impact_of_Remote_Work_on_Mental_Health.xlsx',index=False)

# %%
df_array = np.array(df)
df_1D = np.array(df.iloc[0])
df_2D = np.array(df.iloc[0:3])
df_3D = np.array(df.iloc[0:3,4])

# %%
df.head()
# Out:
#   Employee_ID  Age      Gender           Job_Role    Industry  \
# 0     EMP0001   32  Non-binary                 HR  Healthcare
# 1     EMP0002   40      Female     Data Scientist          IT
# 2     EMP0003   59  Non-binary  Software Engineer   Education
# 3     EMP0004   27        Male  Software Engineer     Finance
# 4     EMP0005   49        Male              Sales  Consulting
#
#    Years_of_Experience Work_Location  Hours_Worked_Per_Week  \
# 0                   13        Hybrid                     47
# 1                    3        Remote                     52
# 2                   22        Hybrid                     46
# 3                   20        Onsite                     32
# 4                   32        Onsite                     35
#
#    Number_of_Virtual_Meetings  Work_Life_Balance_Rating Stress_Level  \
# 0                           7                         2       Medium
# 1                           4                         1       Medium
# 2                          11                         5       Medium
# 3                           8                         4         High
# 4                          12                         2         High
#
#   Mental_Health_Condition Access_to_Mental_Health_Resources  \
# 0              Depression                                No
# 1                 Anxiety                                No
# 2                 Anxiety                                No
# 3              Depression                               Yes
# 4                    Good                               Yes
#
#   Productivity_Change  Social_Isolation_Rating Satisfaction_with_Remote_Work  \
# 0            Decrease                        1                   Unsatisfied
# 1            Increase                        3                     Satisfied
# 2           No Change                        4                   Unsatisfied
# 3            Increase                        3                   Unsatisfied
# 4            Decrease                        3                   Unsatisfied
#
#    Company_Support_for_Remote_Work Physical_Activity Sleep_Quality  \
# 0                                1            Weekly          Good
# 1                                2            Weekly          Good
# 2                                5             Never          Poor
# 3                                3             Never          Poor
# 4                                3            Weekly       Average
#
#           Region
# 0         Europe
# 1           Asia
# 2  North America
# 3         Europe
# 4  North America

# %%
df_agg = df.groupby('Industry')[['Work_Life_Balance_Rating']].mean()
df_agg
# Out:
#                Work_Life_Balance_Rating
# Industry
# Consulting                     2.951471
# Education                      3.013043
# Finance                        2.925033
# Healthcare                     2.978022
# IT                             3.045576
# Manufacturing                  2.879941
# Retail                         3.089532

# %%
import matplotlib.pyplot as plt
plt.stackplot(df_agg.index, df_agg['Work_Life_Balance_Rating'])
plt.show()

# %%
plt.errorbar(df_agg.index, df_agg['Work_Life_Balance_Rating'])
plt.show()
