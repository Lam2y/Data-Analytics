# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel("Call Center_Call Center.xlsx")

# %%
df_array = np.array(df)
df_1D = np.array(df.iloc[0])
df_2D = np.array(df.iloc[0:5])
df_3D = np.array(df.iloc[0:5,3])

# %%
df1 = pd.DataFrame(df.iloc[4], index=range(1,4), columns=df.columns)

# %%
df.columns
# Out:
# Index(['Id', 'Call Timestamp', 'Call-Centres City', 'Channel', 'City',
#        'Customer Name', 'Reason', 'Response Time', 'Sentiment', 'State',
#        'Call Duration In Minutes', 'Csat Score'],
#       dtype='object')

# %%
df_agg = df.groupby('Channel')[['Call Duration In Minutes']].mean()
df_agg
# Out:
#              Call Duration In Minutes
# Channel
# Call-Center                 25.046151
# Chatbot                     24.917757
# Email                       25.098795
# Web                         25.022354

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,5))
plt.stackplot(df_agg.index, df_agg['Call Duration In Minutes'])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,5))
plt.errorbar(df_agg.index, df_agg['Call Duration In Minutes'], yerr=0.1, fmt='o')
plt.xlabel('Channel')
# Out:
# Text(0.5, 0, 'Channel')
