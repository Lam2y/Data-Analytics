# %%
import numpy as np
import pandas as pd
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_22396\1662815981.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_excel("Data Professional.xlsx")

# %%
df_array = np.array(df)
df_1D = np.array(df.iloc[0])
df_2D = np.array(df.iloc[0:3])
df_3D = np.array(df.iloc[0:3,4])

# %%
df1 = pd.DataFrame(df.iloc[1:5].values,index = range(1,5), columns=df.columns)
df1
# Out:
#                   Unique ID      Email Date Taken (America/New_York)  \
# 1  62a33ba1bae91e4b8b82e35c  anonymous                     6/10/2022
# 2  62a33c2cbc6861bf3176bec1  anonymous                     6/10/2022
# 3  62a33c8624a26260273822f9  anonymous                     6/10/2022
# 4  62a33c91f3072dd892621e03  anonymous                     6/10/2022
#
#   Time Taken (America/New_York) Browser   OS City Country Referrer Time Spent  \
# 1                          8:40     NaN  NaN  NaN     NaN      NaN    0:01:30
# 2                          8:42     NaN  NaN  NaN     NaN      NaN    0:02:18
# 3                          8:43     NaN  NaN  NaN     NaN      NaN    0:02:10
# 4                          8:44     NaN  NaN  NaN     NaN      NaN    0:01:51
#
#    ...  \
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#   Q6 - How Happy are you in your Current Position with the following? (Management)  \
# 1                                                2.0
# ...
