# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("laptop_prices.csv")

# %%
df_array = np.array(df)
df_1D = np.array(df.iloc[0])
df_2D = np.array(df.iloc[0:3])
df_3D = np.array(df.iloc[0:3,4])

# %%
df1 = pd.DataFrame( df.iloc[0:3],range(1,3), columns=df.columns)
df1
# Out:
#   Company      Product   TypeName  Inches  Ram     OS  Weight  Price_euros  \
# 1   Apple  Macbook Air  Ultrabook    13.3    8  macOS    1.34       898.94
# 2      HP       250 G6   Notebook    15.6    8  No OS    1.86       575.00
#
#      Screen  ScreenW  ...  RetinaDisplay CPU_company CPU_freq      CPU_model  \
# 1  Standard     1440  ...             No       Intel      1.8        Core i5
# 2   Full HD     1920  ...             No       Intel      2.5  Core i5 7200U
#
#   PrimaryStorage  SecondaryStorage PrimaryStorageType  SecondaryStorageType  \
# 1            128                 0      Flash Storage                    No
# 2            256                 0                SSD                    No
#
#    GPU_company         GPU_model
# 1        Intel  HD Graphics 6000
# 2        Intel   HD Graphics 620
#
# [2 rows x 23 columns]

# %%
#Create a swarmplot of the laptop prices
import seaborn as sns
import matplotlib.pyplot as plt

sns.swarmplot(x='TypeName', y='Price_euros', data=df, hue='Company')
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\seaborn\categorical.py:3399: UserWarning: 33.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\USER\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\seaborn\categorical.py:3399: UserWarning: 78.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\USER\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\seaborn\categorical.py:3399: UserWarning: 24.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
#Create a stripplot of the laptop prices    
sns.stripplot(x='TypeName', y='Price_euros', data=df, hue='Company')
plt.show()
