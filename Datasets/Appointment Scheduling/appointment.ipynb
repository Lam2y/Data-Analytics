# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('Appointment Scheduling Cleaned Data.csv')

# %%
df.head()
# Out:
#     Requesting date   Appointment date Client ID Provider Role First Name  \
# 0  9/20/23 12:18 PM   9/21/23 12:45 PM         1         Nurse      Aayan
# 1  9/20/23 12:19 PM   9/29/23 10:47 AM         2         Nurse     Minnie
# 2   9/20/23 2:56 PM  10/23/23 11:50 AM         3         Nurse     Bianca
# 3   9/20/23 2:56 PM   10/16/23 3:04 PM         4         Nurse   Rosalind
# 4   9/20/23 2:56 PM   10/16/23 3:04 PM         5         Nurse      Zaara
#
#   Last Name       Full Name       Waiting Time
# 0   Johnson   Aayan Johnson   31 days, 0 hours
# 1     Pratt    Minnie Pratt   7 days, 22 hours
# 2   English  Bianca English  31 days, 20 hours
# 3      Love   Rosalind Love   25 days, 0 hours
# 4     Lynch     Zaara Lynch   25 days, 0 hours

# %%
waiting_time = []
for i in df['Waiting Time'].str.split(','):
    waiting_time.append(str(i[0]).strip('days'))
    
    
for i in range(len(df['Waiting Time'])):
    df['Waiting Time'][i] = waiting_time[i]

print(df)
# Out:
#       Requesting date   Appointment date Client ID Provider Role First Name  \
# 0    9/20/23 12:18 PM   9/21/23 12:45 PM         1         Nurse      Aayan
# 1    9/20/23 12:19 PM   9/29/23 10:47 AM         2         Nurse     Minnie
# 2     9/20/23 2:56 PM  10/23/23 11:50 AM         3         Nurse     Bianca
# 3     9/20/23 2:56 PM   10/16/23 3:04 PM         4         Nurse   Rosalind
# 4     9/20/23 2:56 PM   10/16/23 3:04 PM         5         Nurse      Zaara
# ..                ...                ...       ...           ...        ...
# 94  10/18/23 10:03 PM   10/30/23 9:31 PM        95            MD     Samson
# 95   10/31/23 6:46 PM    11/7/23 2:39 PM        96            MD   Ibraheem
# 96   10/19/23 8:48 AM  10/23/23 10:02 AM        97            MD   Cordelia
# 97   10/27/23 1:08 PM  10/30/23 10:45 AM        98            MD     Oliwia
# 98   10/27/23 1:09 PM  10/30/23 10:14 AM        99            MD      Aidan
#
#    Last Name         Full Name Waiting Time
# ...

# %%
df
# Out:
#       Requesting date   Appointment date Client ID Provider Role First Name  \
# 0    9/20/23 12:18 PM   9/21/23 12:45 PM         1         Nurse      Aayan
# 1    9/20/23 12:19 PM   9/29/23 10:47 AM         2         Nurse     Minnie
# 2     9/20/23 2:56 PM  10/23/23 11:50 AM         3         Nurse     Bianca
# 3     9/20/23 2:56 PM   10/16/23 3:04 PM         4         Nurse   Rosalind
# 4     9/20/23 2:56 PM   10/16/23 3:04 PM         5         Nurse      Zaara
# ..                ...                ...       ...           ...        ...
# 94  10/18/23 10:03 PM   10/30/23 9:31 PM        95            MD     Samson
# 95   10/31/23 6:46 PM    11/7/23 2:39 PM        96            MD   Ibraheem
# 96   10/19/23 8:48 AM  10/23/23 10:02 AM        97            MD   Cordelia
# 97   10/27/23 1:08 PM  10/30/23 10:45 AM        98            MD     Oliwia
# 98   10/27/23 1:09 PM  10/30/23 10:14 AM        99            MD      Aidan
#
#    Last Name         Full Name Waiting Time
# ...

# %%
df.rename(columns={"Waiting Time": "Waiting Time (days)"})
# Out:
#       Requesting date   Appointment date Client ID Provider Role First Name  \
# 0    9/20/23 12:18 PM   9/21/23 12:45 PM         1         Nurse      Aayan
# 1    9/20/23 12:19 PM   9/29/23 10:47 AM         2         Nurse     Minnie
# 2     9/20/23 2:56 PM  10/23/23 11:50 AM         3         Nurse     Bianca
# 3     9/20/23 2:56 PM   10/16/23 3:04 PM         4         Nurse   Rosalind
# 4     9/20/23 2:56 PM   10/16/23 3:04 PM         5         Nurse      Zaara
# ..                ...                ...       ...           ...        ...
# 94  10/18/23 10:03 PM   10/30/23 9:31 PM        95            MD     Samson
# 95   10/31/23 6:46 PM    11/7/23 2:39 PM        96            MD   Ibraheem
# 96   10/19/23 8:48 AM  10/23/23 10:02 AM        97            MD   Cordelia
# 97   10/27/23 1:08 PM  10/30/23 10:45 AM        98            MD     Oliwia
# 98   10/27/23 1:09 PM  10/30/23 10:14 AM        99            MD      Aidan
#
#    Last Name         Full Name Waiting Time (days)
# ...

# %%
df.to_excel('Appointment Scheduling Cleaned Data.xlsx',index=False)

# %%
#Create me a dataframe where appointment date is greater than 2020-01-01
df['Appointment date'] = pd.to_datetime(df['Appointment date'])
df1 = pd.DataFrame(df[df['Appointment date'] > '2020-01-01'])
df1
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_21764\1243733815.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Appointment date'] = pd.to_datetime(df['Appointment date'])
#       Requesting date    Appointment date Client ID Provider Role First Name  \
# 0    9/20/23 12:18 PM 2023-09-21 12:45:00         1         Nurse      Aayan
# 1    9/20/23 12:19 PM 2023-09-29 10:47:00         2         Nurse     Minnie
# 2     9/20/23 2:56 PM 2023-10-23 11:50:00         3         Nurse     Bianca
# 3     9/20/23 2:56 PM 2023-10-16 15:04:00         4         Nurse   Rosalind
# 4     9/20/23 2:56 PM 2023-10-16 15:04:00         5         Nurse      Zaara
# ..                ...                 ...       ...           ...        ...
# 94  10/18/23 10:03 PM 2023-10-30 21:31:00        95            MD     Samson
# ...

# %%
df_array = np.array(df)

# %%
df_1D = np.array(df.iloc[0])

# %%
df_2D = np.array(df.iloc[0:5])

# %%
df_3D = np.array(df.iloc[0:5,6])

# %%
df['Waiting Time'] = pd.to_numeric(df['Waiting Time'])

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Assuming df is already defined with 'Appointment date', 'Provider Role', and 'Waiting Time'

# Convert 'Appointment date' to datetime if not already done
df['Appointment date'] = pd.to_datetime(df['Appointment date'])

# Aggregate by month and provider role
df_agg = df.groupby([df['Appointment date'].dt.month, 'Provider Role'])['Waiting Time'].mean().unstack(fill_value=0)

df_agg
# Plot
plt.figure(figsize=(8, 5))
plt.stackplot(df_agg.index, df_agg.T, labels=df_agg.columns, alpha=0.8)
plt.legend(title="Provider Role", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xlabel("Month")
plt.ylabel("Average Waiting Time")
plt.show()

# %%
df.isna().sum()
# Out:
# Requesting date     0
# Appointment date    0
# Client ID           0
# Provider Role       0
# First Name          0
# Last Name           0
# Full Name           0
# Waiting Time        0
# dtype: int64

# %%
# Create me errorbar by provider role
import matplotlib.pyplot as plt
import pandas
import numpy as np

# Assuming df is already defined with 'Appointment date', 'Provider Role', and 'Waiting Time'

# Convert 'Appointment date' to datetime if not already done
df['Appointment date'] = pd.to_datetime(df['Appointment date'])

# Aggregate by month and provider role
df_agg = df.groupby([df['Appointment date'].dt.month, 'Provider Role'])['Waiting Time'].mean().unstack(fill_value=0)

# Calculate standard deviation
df_std = df.groupby([df['Appointment date'].dt.month, 'Provider Role'])['Waiting Time'].std().unstack(fill_value=0)

# Plot
plt.figure(figsize=(8, 5))
for i, role in enumerate(df_agg.columns):
    plt.errorbar(df_agg.index, df_agg[role], yerr=df_std[role], label=role, alpha=0.8)
plt.legend(title="Provider Role", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xlabel("Month")
plt.ylabel("Average Waiting Time")
plt.show()

# %%
#Visualize the distribution of waiting times using a histogram with seaborn.
import seaborn as sns
sns.histplot(df['Waiting Time'])
# Out:
# <Axes: xlabel='Waiting Time', ylabel='Count'>

# %%
#Compare the number of appointments for different provider roles using a bar plot in seaborn.
df
# Out:
#       Requesting date    Appointment date Client ID Provider Role First Name  \
# 0    9/20/23 12:18 PM 2023-09-21 12:45:00         1         Nurse      Aayan
# 1    9/20/23 12:19 PM 2023-09-29 10:47:00         2         Nurse     Minnie
# 2     9/20/23 2:56 PM 2023-10-23 11:50:00         3         Nurse     Bianca
# 3     9/20/23 2:56 PM 2023-10-16 15:04:00         4         Nurse   Rosalind
# 4     9/20/23 2:56 PM 2023-10-16 15:04:00         5         Nurse      Zaara
# ..                ...                 ...       ...           ...        ...
# 94  10/18/23 10:03 PM 2023-10-30 21:31:00        95            MD     Samson
# 95   10/31/23 6:46 PM 2023-11-07 14:39:00        96            MD   Ibraheem
# 96   10/19/23 8:48 AM 2023-10-23 10:02:00        97            MD   Cordelia
# 97   10/27/23 1:08 PM 2023-10-30 10:45:00        98            MD     Oliwia
# 98   10/27/23 1:09 PM 2023-10-30 10:14:00        99            MD      Aidan
#
#    Last Name         Full Name  Waiting Time
# ...

# %%
#Analyze the average waiting time for each provider role Using a box plot in seaborn.
sns.boxplot(x=df['Waiting Time'],hue=df['Provider Role'])
# Out:
# <Axes: xlabel='Waiting Time'>

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Assuming you have a DataFrame `df` with the relevant columns
# Convert 'Requesting date' and 'Appointment date' to datetime format if necessary
df['Requesting date'] = pd.to_datetime(df['Requesting date'])
df['Appointment date'] = pd.to_datetime(df['Appointment date'])

# Plot the data (Requesting date vs Appointment date)
plt.figure(figsize=(10, 6))
plt.plot(df['Requesting date'], df['Appointment date'], marker='o', linestyle='-', color='b')

# Add labels and title
plt.xlabel('Requesting Date')
plt.ylabel('Appointment Date')
plt.title('Time Trend of Appointments Over Time')

# Rotate x-axis labels for readability if necessary
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()
plt.show()

# %%
#Display the relationship between requesting time and appointment time for all clients.
#Plot: Use a scatter plot in matplotlib.
plt.scatter(df['Requesting date'], df['Appointment date'])

# %%
#Highlight the client with the longest waiting time.
#Plot: Use an annotated bar plot in matplotlib.

# %%
#Analyze the spread of waiting times for all clients.
#Plot: Use a violin plot in seaborn.

# %%
#Compare the proportion of waiting times greater than 7 days between provider roles.
#Plot: Use a pie chart in matplotlib.

# %%
#Correlate appointment dates and waiting times to identify patterns.
#Plot: Use a scatter plot in seaborn with a regression line.

# %%
#Show the frequency of appointment times in different time slots (morning, afternoon, etc.).
#Plot: Use a stacked bar chart in matplotlib.
