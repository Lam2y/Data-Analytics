# %%
import numpy as np
import pandas as pd
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_13364\1662815981.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_excel("Customer Purchasing Behaviors.xlsx")

# %%
df_array = np.array(df)
df_1D = np.array(df.iloc[0])
df_2D = np.array(df.iloc[0:3])
df_3D = np.array(df.iloc[0:3,4])

# %%
df1 = pd.DataFrame(df.iloc[0:5], range(1,4), columns=df.columns)
df1
# Out:
#    user_id  age  annual_income  purchase_amount  loyalty_score region  \
# 1        2   34          55000              350            7.0  South
# 2        3   45          65000              500            8.0   West
# 3        4   22          30000              150            3.0   East
#
#    purchase_frequency
# 1                  18
# 2                  22
# 3                  10

# %%
df_agg = df.groupby('region')[['annual_income']].mean()
df_agg
# Out:
#         annual_income
# region
# East     49000.000000
# North    53038.461538
# South    55766.233766
# West     64129.870130

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,8))
plt.stackplot(df_agg.index, df_agg['annual_income'])
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.errorbar(df_agg.index, df_agg['annual_income'], yerr=50)
plt.show()
